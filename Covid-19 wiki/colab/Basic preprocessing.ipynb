# %%
# Connect to Google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pip install -U spacy==2.1.0 
# !python -m spacy download en
# !pip install Cython --install-option="--no-cython-compile"
# !pip uninstall -y neuralcoref 
# !pip install neuralcoref --no-binary neuralcoref
# !python -m spacy download en_core_web_lg
# Out:
# Requirement already up-to-date: spacy==2.1.0 in /usr/local/lib/python3.7/dist-packages (2.1.0)
# Requirement already satisfied, skipping upgrade: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.1.0) (2.23.0)
# Requirement already satisfied, skipping upgrade: jsonschema<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.1.0) (2.6.0)
# Requirement already satisfied, skipping upgrade: preshed<2.1.0,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from spacy==2.1.0) (2.0.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.1.0) (1.19.5)
# Requirement already satisfied, skipping upgrade: srsly<1.1.0,>=0.0.5 in /usr/local/lib/python3.7/dist-packages (from spacy==2.1.0) (1.0.5)
# Requirement already satisfied, skipping upgrade: wasabi<1.1.0,>=0.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy==2.1.0) (0.8.2)
# Requirement already satisfied, skipping upgrade: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy==2.1.0) (2.0.5)
# Requirement already satisfied, skipping upgrade: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.1.0) (1.0.5)
# Requirement already satisfied, skipping upgrade: plac<1.0.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy==2.1.0) (0.9.6)
# Requirement already satisfied, skipping upgrade: blis<0.3.0,>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from spacy==2.1.0) (0.2.4)
# Requirement already satisfied, skipping upgrade: thinc<7.1.0,>=7.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy==2.1.0) (7.0.8)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.1.0) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.1.0) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.1.0) (1.24.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.1.0) (2021.5.30)
# Requirement already satisfied, skipping upgrade: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python3.7/dist-packages (from thinc<7.1.0,>=7.0.2->spacy==2.1.0) (4.41.1)
# Requirement already satisfied: en_core_web_sm==2.1.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.1.0/en_core_web_sm-2.1.0.tar.gz#egg=en_core_web_sm==2.1.0 in /usr/local/lib/python3.7/dist-packages (2.1.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')
# /usr/local/lib/python3.7/dist-packages/pip/_internal/commands/install.py:283: UserWarning: Disabling all use of wheels due to the use of --build-options / --global-options / --install-options.
#   cmdoptions.check_install_build_global(options)
# Requirement already satisfied: Cython in /usr/local/lib/python3.7/dist-packages (0.29.23)
# Uninstalling neuralcoref-4.0:
#   Successfully uninstalled neuralcoref-4.0
# Collecting neuralcoref
#   Using cached https://files.pythonhosted.org/packages/0c/40/8db3db763077fe80b71859f57731261aeb03cc624635f97a3bcfe55ab37b/neuralcoref-4.0.tar.gz
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from neuralcoref) (1.19.5)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (from neuralcoref) (1.17.97)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from neuralcoref) (2.23.0)
# Requirement already satisfied: spacy>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from neuralcoref) (2.1.0)
# Requirement already satisfied: s3transfer<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from boto3->neuralcoref) (0.4.2)
# Requirement already satisfied: botocore<1.21.0,>=1.20.97 in /usr/local/lib/python3.7/dist-packages (from boto3->neuralcoref) (1.20.97)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3->neuralcoref) (0.10.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (3.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.1.0->neuralcoref) (1.0.5)
# Requirement already satisfied: blis<0.3.0,>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.1.0->neuralcoref) (0.2.4)
# Requirement already satisfied: preshed<2.1.0,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.1.0->neuralcoref) (2.0.1)
# Requirement already satisfied: thinc<7.1.0,>=7.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.1.0->neuralcoref) (7.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.1.0->neuralcoref) (2.0.5)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.1.0->neuralcoref) (0.9.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.1.0->neuralcoref) (0.8.2)
# Requirement already satisfied: jsonschema<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.1.0->neuralcoref) (2.6.0)
# Requirement already satisfied: srsly<1.1.0,>=0.0.5 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.1.0->neuralcoref) (1.0.5)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.21.0,>=1.20.97->boto3->neuralcoref) (2.8.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python3.7/dist-packages (from thinc<7.1.0,>=7.0.2->spacy>=2.1.0->neuralcoref) (4.41.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.21.0,>=1.20.97->boto3->neuralcoref) (1.15.0)
# Skipping wheel build for neuralcoref, due to binaries being disabled for it.
# Installing collected packages: neuralcoref
#     Running setup.py install for neuralcoref ... done
# Successfully installed neuralcoref-4.0
# Requirement already satisfied: en_core_web_lg==2.1.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.1.0/en_core_web_lg-2.1.0.tar.gz#egg=en_core_web_lg==2.1.0 in /usr/local/lib/python3.7/dist-packages (2.1.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_lg')

# %%
import re
import spacy
import neuralcoref

# %%
# Load SpaCy
nlp = spacy.load('en_core_web_lg')
# Add neural coref to SpaCy's pipe
neuralcoref.add_to_pipe(nlp)

# %%
import pandas as pd

# %%
path = "/content/gdrive/MyDrive/Nguyễn Đình Lâm-Project 2-Knowledge Graph/Covid-19 wiki/input/"

# %%
covid19_df = pd.read_csv(path + "raw-covid19-wiki.csv")

# %%
covid19_df
# Out:
#     Unnamed: 0  ...                                               link
# 0            0  ...             https://en.wikipedia.org/wiki/COVID-19
# 1            1  ...    https://en.wikipedia.org/wiki/COVID-19 pandemic
# 2            2  ...     https://en.wikipedia.org/wiki/COVID-19 vaccine
# 3            3  ...  https://en.wikipedia.org/wiki/Severe acute res...
# 4            4  ...  https://en.wikipedia.org/wiki/COVID-19 misinfo...
# 5            5  ...    https://en.wikipedia.org/wiki/Social distancing
# 6            6  ...  https://en.wikipedia.org/wiki/Transmission (me...
# 7            7  ...  https://en.wikipedia.org/wiki/Symptoms of COVI...
# 8            8  ...     https://en.wikipedia.org/wiki/COVID-19 testing
# 9            9  ...  https://en.wikipedia.org/wiki/Workplace hazard...
# 10          10  ...  https://en.wikipedia.org/wiki/COVID-19 drug de...
# 11          11  ...  https://en.wikipedia.org/wiki/Economic impact ...
#
# [12 rows x 4 columns]

# %%
def coref_resolution(text):
    """Function that executes coreference resolution on a given text"""
    doc = nlp(text)
    # fetches tokens with whitespaces from spacy document
    tok_list = list(token.text_with_ws for token in doc)
    for cluster in doc._.coref_clusters:
        # get tokens from representative cluster name
        cluster_main_words = set(cluster.main.text.split(' '))
        for coref in cluster:
            if coref != cluster.main:  # if coreference element is not the representative element of that cluster
                if coref.text != cluster.main.text and bool(set(coref.text.split(' ')).intersection(cluster_main_words)) == False:
                    # if coreference element text and representative element text are not equal and none of the coreference element words are in representative element. This was done to handle nested coreference scenarios
                    tok_list[coref.start] = cluster.main.text + \
                        doc[coref.end-1].whitespace_
                    for i in range(coref.start+1, coref.end):
                        tok_list[i] = ""

    return "".join(tok_list)

# %%
def preprocess(text, coref=True):
    # preprocess text
    text = text.replace('\n', ' ')
    text = re.sub(r'\[.*?\]+', ' ', text)
    text = re.sub(r'\n+', ' ', text)  # replace multiple newlines with period
    text = re.sub(r'\[\d+\]', ' ', text)  # remove reference numbers
    if coref:
        text = coref_resolution(text)  # resolve coreference clusters
    return text

# %%
covid19_df['text'] = covid19_df['text'].apply(preprocess)

# %%
test = covid19_df.loc[0, 'text']

# %%
test = nlp(test)

# %%
test._.coref_clusters
# Out:
# [      Coronavirus disease 2019 (COVID-19): [      Coronavirus disease 2019 (COVID-19), The disease],
#  Symptoms of COVID-19: [Symptoms of COVID-19, Symptoms],
#        Coronavirus disease 2019 (COVID-19): [      Coronavirus disease 2019 (COVID-19), the disease],
#  airborne particles: [airborne particles, Those particles],
#  Wuhan: [Wuhan, Wuhan, Wuhan, Wuhan],
#  the WHO: [the WHO, the WHO],
#  China: [China, China, China, China, China],
#  COVID-19: [COVID-19, COVID-19, COVID-19],
#  the people who are infected with the virus: [the people who are infected with the virus, the people who are infected with the virus],
#  the virus: [the virus, the virus, the virus, the virus, the virus, the virus, the virus],
#  the disease: [the disease, The disease, the disease],
#  a delay between the moment a person first becomes infected and the appearance of the first symptoms: [a delay between the moment a person first becomes infected and the appearance of the first symptoms, The median delay for COVID-19],
#  COVID-19: [COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, managing COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19, COVID-19],
#  SARS-CoV-2: [SARS-CoV-2, SARS-CoV-2, SARS-CoV-2, SARS-CoV-2, SARS-CoV-2, SARS-CoV-2, SARS-CoV-2, SARS-CoV-2, SARS-CoV-2, SARS-CoV-2, SARS-CoV-2, SARS-CoV-2, SARS-CoV-2, SARS-CoV-2, SARS-CoV-2, SARS-CoV-2],
#  Wuhan: [Wuhan, Wuhan],
#  the virus: [the virus, the virus, The virus, The virus, The virus, The virus, The virus, this virus],
#  the spike protein (S): [the spike protein (S), The M protein of SARS-CoV-2, the M protein, The M protein, the spike protein (S)],
#  lungs: [lungs, The lungs, the lungs, the lungs],
#  the CNS of the majority of COVID-19 people with neurological issues: [the CNS of the majority of COVID-19 people with neurological issues, the CNS, the CNS, the CNS, the CNS],
#  New York: [New York, New York],
#  The S-protein, otherwise known as the spike protein: [The S-protein, otherwise known as the spike protein, The S-protein, otherwise known as the spike protein, The N and E protein, the SARS-CoV-2 S protein (particularly the S2 subunit) and about 50%],
#  the spike protein: [the spike protein, the spike protein],
#  S2: [S2, S2],
#  a cytokine storm: [a cytokine storm, the cytokine storm, the cytokine storm],
#  A cytokine storm: [A cytokine storm, The storm],
#  they: [they, they],
#  CT: [CT, CT],
#  a past infection: [a past infection, the infection, the infection],
#  the disease: [the disease, the disease, the disease, the disease, the disease, The disease, the disease, the disease, the disease, the disease, the disease, the disease, the disease, the disease, the disease],
#  Oxford: [Oxford, Oxford],
#  at least twenty seconds: [at least twenty seconds, at least twenty seconds],
#  the CDC: [the CDC, the CDC, The CDC, CDC, the CDC, CDC, The CDC, The CDC, CDC, The CDC, CDC],
#  COVID-19: [COVID-19, COVID-19],
#  The first COVID-19 vaccine: [The first COVID-19 vaccine, The first COVID-19 vaccine],
#  the SARS-CoV-2 virus: [the SARS-CoV-2 virus, the virus, the virus, the SARS-CoV-2 virus, the SARS-CoV-2 virus, the virus, the virus, the SARS-CoV-2 virus, the virus, the virus, the virus, The virus, the SARS-CoV-2 virus, the virus, the virus],
#  the COVID‑19 pandemic: [the COVID‑19 pandemic, the pandemic],
#  COVID‑19: [COVID‑19, COVID‑19],
#  March 2021: [March 2021, March 2021],
#  CDC: [CDC, CDC],
#  two formulations for local production: [two formulations for local production, these formulations],
#  the prisoner population: [the prisoner population, the prisoner population],
#  the body: [the body, the body],
#  Coronaviruses: [Coronaviruses, Coronaviruses],
#  SARS-CoV-2: [SARS-CoV-2, SARS-CoV-2, SARS-CoV-2, SARS-CoV-2, SARS-CoV-2, SARS-CoV-2, SARS-CoV-2],
#  A 2021 Cochrane rapid review: [A 2021 Cochrane rapid review, The review],
#  Disease Control and Prevention: [Disease Control and Prevention, Disease Control and Prevention, Disease Control and Prevention],
#  those who suspect they are carrying the virus: [those who suspect they are carrying the virus, they],
#  the glucocorticoid dexamethasone: [the glucocorticoid dexamethasone, the glucocorticoid dexamethasone],
#  an ICU: [an ICU, ICU, ICU],
#  WHO chief Tedros Adhanom: [WHO chief Tedros Adhanom, chief Tedros Adhanom],
#  the US: [the US, the US, the US, the US],
#  a European multinational study of hospitalized children from June 2020: [a European multinational study of hospitalized children from June 2020, the European study, the study],
#  acute encephalopathy: [acute encephalopathy, acute encephalopathy],
#  the virus: [the virus, the virus],
#  The mortality rate: [The mortality rate, the mortality rate],
#  India: [India, India, India],
#  The CFR: [The case fatality rate (CFR), The CFR, the CFR, the CFR, CFR],
#  A key metric in gauging the severity of COVID-19: [A key metric in gauging the severity of COVID-19, This metric],
#  the IFR: [the IFR, population IFR, IFR, IFR, IFR, IFR, IFR, IFR, IFR, the IFR, IFR, IFR],
#  December 2020: [December 2020, December 2020],
#  the pandemic: [the pandemic, the pandemic, the pandemic, the pandemic, the pandemic, the virus, the virus, the virus, the virus, the virus, the virus, the pandemic, the virus, the virus, the pandemic, the virus, the virus, the pandemic, the virus, the COVID-19 virus, the virus, the pandemic],
#  Italy: [Italy, Italy, Italy, Italy, Italy, Italy, Italy, Italy, Italy, Italy, Italy],
#  the WHO: [the WHO, the WHO, The WHO, the WHO],
#  Europe: [Europe, Europe],
#  New York City: [New York City, New York City, New York City],
#  Prevention: [Prevention, Prevention],
#  China: [China, China, China, China, China, China, China, China, China, China],
#  influenza and SARS: [influenza and SARS, influenza and SARS],
#  SARS: [SARS, SARS, SARS],
#  The source: [The source, The source],
#  COVID-19: [COVID-19, COVID-19],
#  the United States: [the United States, the United States, the United States, the United States, the United Kingdom],
#  the CDC: [the CDC, the CDC, the CDC, the U.S. CDC, CDC, The CDC, CDC, the CDC],
#  TB: [TB, TB],
#  SARS-CoV-2: [SARS-CoV-2, SARS-CoV-2, SARS-CoV-2, SARS-CoV-2, SARS-CoV-2, SARS-CoV-2, SARS-CoV-2, SARS-CoV-2, SARS-CoV-2],
#  Wuhan: [Wuhan, Wuhan, Wuhan],
#  Hubei: [Hubei, Hubei],
#  The Lancet: [The Lancet, The Lancet],
#  May 2020: [May 2020, May 2020],
#  the seafood market: [the seafood market, the market],
#  the initial outbreak: [the initial outbreak, the outbreak, the outbreak],
#  December 2019: [December 2019, December 2019],
#  31 December: [31 December, 31 December],
#  Wuhan Central Hospital: [Wuhan Central Hospital, Wuhan Central Hospital, Wuhan Central Hospital],
#  sequencing company Vision Medicals: [sequencing company Vision Medicals, Vision Medicals],
#  an erroneous positive result for SARS: [an erroneous positive result for SARS, the result],
#  The Wuhan Municipal Health Commission: [The Wuhan Municipal Health Commission, The Wuhan Municipal Health Commission],
#  France: [France, France, France],
#  September 2020: [September 2020, September 2020, September 2020, September 2020],
#  COVID-19: [COVID-19, COVID-19],
#  the COVID-19 infection: [the COVID-19 infection, this infection],
#  preliminary estimates of the risk of death by age groups in the United States: [preliminary estimates of the risk of death by age groups in the United States, those estimates],
#  November 2020: [November 2020, November 2020],
#  they: [they, they],
#  this: [this, this],
#  COVID-19: [COVID-19, COVID-19],
#  Drug: [Drug, Drug, Drug, Drug],
#  the U.S. Food and Drug Administration (FDA): [the U.S. Food and Drug Administration (FDA), the FDA, the U.S. Food and Drug Administration (FDA), FDA],
#  Bamlanivimab: [Bamlanivimab, Bamlanivimab, Bamlanivimab],
#  the the U.S. Food and Drug Administration (FDA): [the the U.S. Food and Drug Administration (FDA), the the U.S. Food and Drug Administration (FDA)],
#  COVID-19: [COVID-19, COVID-19],
#  Tocilizumab: [Tocilizumab, Tocilizumab],
#  cytokine release syndrome: [cytokine release syndrome, cytokine release syndrome],
#  those who have recovered from COVID-19 to people who need them: [those who have recovered from COVID-19 to people who need them, them],
#  The spike protein of SARS-CoV-2: [The spike protein of SARS-CoV-2, the spike protein of SARS-CoV-2, the spike protein of SARS-CoV-2],
#  eight neutralizing antibodies targeting the spike protein of SARS-CoV-2: [eight neutralizing antibodies targeting the spike protein of SARS-CoV-2, eight neutralizing antibodies targeting the spike protein of SARS-CoV-2],
#  SARS: [SARS, SARS],
#  COVID-19: [COVID-19, COVID-19]]

# %%
covid19_df.to_csv(path + "covid19-wiki.csv", index=True)

# %%
covid19_df
# Out:
#     Unnamed: 0  ...                                               link
# 0            0  ...             https://en.wikipedia.org/wiki/COVID-19
# 1            1  ...    https://en.wikipedia.org/wiki/COVID-19 pandemic
# 2            2  ...     https://en.wikipedia.org/wiki/COVID-19 vaccine
# 3            3  ...  https://en.wikipedia.org/wiki/Severe acute res...
# 4            4  ...  https://en.wikipedia.org/wiki/COVID-19 misinfo...
# 5            5  ...    https://en.wikipedia.org/wiki/Social distancing
# 6            6  ...  https://en.wikipedia.org/wiki/Transmission (me...
# 7            7  ...  https://en.wikipedia.org/wiki/Symptoms of COVI...
# 8            8  ...     https://en.wikipedia.org/wiki/COVID-19 testing
# 9            9  ...  https://en.wikipedia.org/wiki/Workplace hazard...
# 10          10  ...  https://en.wikipedia.org/wiki/COVID-19 drug de...
# 11          11  ...  https://en.wikipedia.org/wiki/Economic impact ...
#
# [12 rows x 4 columns]
